# %% [markdown]
# <a href="https://colab.research.google.com/github/vaishnavidahale-cyber/My-first-aap/blob/main/Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Expression Tree Generator and Evaluator
## Data Structures Project

# %%
# Node class for Expression Tree
class Node:
    def __init__(self, value):
        self.value = value
        self.left = None
        self.right = None


# Expression Tree class
class ExpressionTree:
    def __init__(self, expression):
        self.expression = expression
        self.root = None


print("Basic structure of Expression Tree created.")
# Out:
# Basic structure of Expression Tree created.
